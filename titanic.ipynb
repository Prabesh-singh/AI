# %%
import pandas as  pd

# %%
df = pd.read_csv("titanic.csv")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
df.head(5)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
fare = df[['Fare']]

# %%
fare.head(5)
# Out:
#       Fare
# 0   7.2500
# 1  71.2833
# 2   7.9250
# 3  53.1000
# 4   8.0500

# %%
class_age = df[['Pclass','Age']]

# %%
class_age.head(5)
# Out:
#    Pclass   Age
# 0       3  22.0
# 1       1  38.0
# 2       3  26.0
# 3       1  35.0
# 4       3  35.0

# %%
survived_gender = df[['Survived', 'Age']]

# %%
survived_gender.head(5)
# Out:
#    Survived   Age
# 0         0  22.0
# 1         1  38.0
# 2         1  26.0
# 3         1  35.0
# 4         0  35.0

# %%
# Problem - 2 - Subsetting:

# %%
fare_gt_100 = df[df['Fare']>100]

# %%
fare_gt_100.head(5)
# Out:
#      PassengerId  Survived  Pclass  \
# 27            28         0       1
# 31            32         1       1
# 88            89         1       1
# 118          119         0       1
# 195          196         1       1
#
#                                                Name     Sex   Age  SibSp  \
# 27                   Fortune, Mr. Charles Alexander    male  19.0      3
# 31   Spencer, Mrs. William Augustus (Marie Eugenie)  female   NaN      1
# 88                       Fortune, Miss. Mabel Helen  female  23.0      3
# 118                        Baxter, Mr. Quigg Edmond    male  24.0      0
# 195                            Lurette, Miss. Elise  female  58.0      0
#
#      Parch    Ticket      Fare        Cabin Embarked      fare
# 27       2     19950  263.0000  C23 C25 C27        S  263.0000
# 31       0  PC 17569  146.5208          B78        C  146.5208
# 88       2     19950  263.0000  C23 C25 C27        S  263.0000
# 118      1  PC 17558  247.5208      B58 B60        C  247.5208
# 195      0  PC 17569  146.5208          B80        C  146.5208

# %%
first_class = df[df['Pclass']==1]

# %%
first_class.head(5)
# Out:
#     PassengerId  Survived  Pclass  \
# 1             2         1       1
# 3             4         1       1
# 6             7         0       1
# 11           12         1       1
# 23           24         1       1
#
#                                                  Name     Sex   Age  SibSp  \
# 1   Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 3        Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 6                             McCarthy, Mr. Timothy J    male  54.0      0
# 11                           Bonnell, Miss. Elizabeth  female  58.0      0
# 23                       Sloper, Mr. William Thompson    male  28.0      0
#
#     Parch    Ticket     Fare Cabin Embarked     fare
# 1       0  PC 17599  71.2833   C85        C  71.2833
# 3       0    113803  53.1000  C123        S  53.1000
# 6       0     17463  51.8625   E46        S  51.8625
# 11      0    113783  26.5500  C103        S  26.5500
# 23      0    113788  35.5000    A6        S  35.5000

# %%
female_under_18 = df[(df['Age']<18) &(df['Sex']=='female')]

# %%
female_under_18.head(5)
# Out:
#     PassengerId  Survived  Pclass                                  Name  \
# 9            10         1       2   Nasser, Mrs. Nicholas (Adele Achem)
# 10           11         1       3       Sandstrom, Miss. Marguerite Rut
# 14           15         0       3  Vestrom, Miss. Hulda Amanda Adolfina
# 22           23         1       3           McGowan, Miss. Anna "Annie"
# 24           25         0       3         Palsson, Miss. Torborg Danira
#
#        Sex   Age  SibSp  Parch   Ticket     Fare Cabin Embarked     fare
# 9   female  14.0      1      0   237736  30.0708   NaN        C  30.0708
# 10  female   4.0      1      1  PP 9549  16.7000    G6        S  16.7000
# 14  female  14.0      0      0   350406   7.8542   NaN        S   7.8542
# 22  female  15.0      0      0   330923   8.0292   NaN        Q   8.0292
# 24  female   8.0      3      1   349909  21.0750   NaN        S  21.0750

# %%
# Subsetting Rows by Categorical variables:
embarked_c_or_s = df[df['Embarked'].isin(['C','S'])]

# %%
embarked_c_or_s.head(5)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked     fare
# 0      0         A/5 21171   7.2500   NaN        S   7.2500
# 1      0          PC 17599  71.2833   C85        C  71.2833
# 2      0  STON/O2. 3101282   7.9250   NaN        S   7.9250
# 3      0            113803  53.1000  C123        S  53.1000
# 4      0            373450   8.0500   NaN        S   8.0500

# %%
first_second_class = df[df['Pclass'].isin([1,2])]

# %%
first_second_class.head(5)
# Out:
#     PassengerId  Survived  Pclass  \
# 1             2         1       1
# 3             4         1       1
# 6             7         0       1
# 9            10         1       2
# 11           12         1       1
#
#                                                  Name     Sex   Age  SibSp  \
# 1   Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 3        Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 6                             McCarthy, Mr. Timothy J    male  54.0      0
# 9                 Nasser, Mrs. Nicholas (Adele Achem)  female  14.0      1
# 11                           Bonnell, Miss. Elizabeth  female  58.0      0
#
#     Parch    Ticket     Fare Cabin Embarked     fare
# 1       0  PC 17599  71.2833   C85        C  71.2833
# 3       0    113803  53.1000  C123        S  53.1000
# 6       0     17463  51.8625   E46        S  51.8625
# 9       0    237736  30.0708   NaN        C  30.0708
# 11      0    113783  26.5500  C103        S  26.5500

# %%
# Exploratory Data Analysis Practice Exercise - 1.
df['fare_per_year'] = df.groupby('Sex')['Fare'].transform(lambda x:x/x.mean())

# %%
df.head(5)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked     fare  fare_per_year
# 0      0         A/5 21171   7.2500   NaN        S   7.2500       0.284048
# 1      0          PC 17599  71.2833   C85        C  71.2833       1.602599
# 2      0  STON/O2. 3101282   7.9250   NaN        S   7.9250       0.178171
# 3      0            113803  53.1000  C123        S  53.1000       1.193800
# 4      0            373450   8.0500   NaN        S   8.0500       0.315391

# %%
high_fare_age = df[df['fare_per_year']>5]

# %%
high_fare_age.head(5)
# Out:
#      PassengerId  Survived  Pclass  \
# 27            28         0       1
# 88            89         1       1
# 118          119         0       1
# 258          259         1       1
# 299          300         1       1
#
#                                                 Name     Sex   Age  SibSp  \
# 27                    Fortune, Mr. Charles Alexander    male  19.0      3
# 88                        Fortune, Miss. Mabel Helen  female  23.0      3
# 118                         Baxter, Mr. Quigg Edmond    male  24.0      0
# 258                                 Ward, Miss. Anna  female  35.0      0
# 299  Baxter, Mrs. James (Helene DeLaudeniere Chaput)  female  50.0      0
#
#      Parch    Ticket      Fare        Cabin Embarked      fare  fare_per_year
# 27       2     19950  263.0000  C23 C25 C27        S  263.0000      10.304071
# 88       2     19950  263.0000  C23 C25 C27        S  263.0000       5.912794
# 118      1  PC 17558  247.5208      B58 B60        C  247.5208       9.697611
# 258      0  PC 17755  512.3292          NaN        C  512.3292      11.518240
# 299      1  PC 17558  247.5208      B58 B60        C  247.5208       5.564789

# %%
high_fare_age_srt = df.sort_values(by='fare_per_year', ascending=False)

# %%
high_fare_age_srt.head(5)
# Out:
#      PassengerId  Survived  Pclass                                Name  \
# 679          680         1       1  Cardeza, Mr. Thomas Drake Martinez
# 737          738         1       1              Lesurer, Mr. Gustave J
# 258          259         1       1                    Ward, Miss. Anna
# 438          439         0       1                   Fortune, Mr. Mark
# 27            28         0       1      Fortune, Mr. Charles Alexander
#
#         Sex   Age  SibSp  Parch    Ticket      Fare        Cabin Embarked  \
# 679    male  36.0      0      1  PC 17755  512.3292  B51 B53 B55        C
# 737    male  35.0      0      0  PC 17755  512.3292         B101        C
# 258  female  35.0      0      0  PC 17755  512.3292          NaN        C
# 438    male  64.0      1      4     19950  263.0000  C23 C25 C27        S
# 27     male  19.0      3      2     19950  263.0000  C23 C25 C27        S
#
#          fare  fare_per_year
# 679  512.3292      20.072533
# 737  512.3292      20.072533
# 258  512.3292      11.518240
# 438  263.0000      10.304071
# 27   263.0000      10.304071

# %%
result = df[['Name','fare_per_year']]

# %%
result.head(5)
# Out:
#                                                 Name  fare_per_year
# 0                            Braund, Mr. Owen Harris       0.284048
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...       1.602599
# 2                             Heikkinen, Miss. Laina       0.178171
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)       1.193800
# 4                           Allen, Mr. William Henry       0.315391

# %%
# Which adult male passenger (age ≥ 18 and Sex is ’male’) paid the highest fare relative to their class?
df['fare_per_class'] = df.groupby('fare')['Pclass'].transform(lambda x:x/x.mean())

# %%
df.head(3)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
#
#    Parch            Ticket     Fare Cabin Embarked     fare  fare_per_year  \
# 0      0         A/5 21171   7.2500   NaN        S   7.2500       0.284048
# 1      0          PC 17599  71.2833   C85        C  71.2833       1.602599
# 2      0  STON/O2. 3101282   7.9250   NaN        S   7.9250       0.178171
#
#    fare_per_class
# 0             1.0
# 1             1.0
# 2             1.0

# %%
adult_males = df[(df['Sex']=='male') &(df['Age']>=18)]

# %%
adult_males.head(5)
# Out:
#     PassengerId  Survived  Pclass                            Name   Sex   Age  \
# 0             1         0       3         Braund, Mr. Owen Harris  male  22.0
# 4             5         0       3        Allen, Mr. William Henry  male  35.0
# 6             7         0       1         McCarthy, Mr. Timothy J  male  54.0
# 12           13         0       3  Saundercock, Mr. William Henry  male  20.0
# 13           14         0       3     Andersson, Mr. Anders Johan  male  39.0
#
#     SibSp  Parch     Ticket     Fare Cabin Embarked     fare  fare_per_year  \
# 0       1      0  A/5 21171   7.2500   NaN        S   7.2500       0.284048
# 4       0      0     373450   8.0500   NaN        S   8.0500       0.315391
# 6       0      0      17463  51.8625   E46        S  51.8625       2.031920
# 12      0      0  A/5. 2151   8.0500   NaN        S   8.0500       0.315391
# 13      1      5     347082  31.2750   NaN        S  31.2750       1.225322
#
#     fare_per_class
# 0              1.0
# 4              1.0
# 6              1.0
# 12             1.0
# 13             1.0

# %%
adult_males_srt = df.sort_values(by='fare_per_class', ascending = False)

# %%
adult_males_srt.head(3)
# Out:
#      PassengerId  Survived  Pclass                          Name     Sex  \
# 580          581         1       2   Christy, Miss. Julie Rachel  female
# 361          362         0       2     del Carlo, Mr. Sebastiano    male
# 271          272         1       3  Tornquist, Mr. William Henry    male
#
#       Age  SibSp  Parch         Ticket     Fare Cabin Embarked     fare  \
# 580  25.0      1      1         237789  30.0000   NaN        S  30.0000
# 361  29.0      1      0  SC/PARIS 2167  27.7208   NaN        C  27.7208
# 271  25.0      0      0           LINE   0.0000   NaN        S   0.0000
#
#      fare_per_year  fare_per_class
# 580       0.674463        1.714286
# 361       1.086073        1.666667
# 271       0.000000        1.551724

# %%
adult_males_srt[['Name','Age','fare_per_class']].head()
# Out:
#                                 Name   Age  fare_per_class
# 580      Christy, Miss. Julie Rachel  25.0        1.714286
# 361        del Carlo, Mr. Sebastiano  29.0        1.666667
# 271     Tornquist, Mr. William Henry  25.0        1.551724
# 302  Johnson, Mr. William Cahoone Jr  19.0        1.551724
# 179              Leonard, Mr. Lionel  36.0        1.551724
